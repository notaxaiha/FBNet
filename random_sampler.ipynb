# %%
from supernet_functions import lookup_table_builder
import numpy as np

from IPython.display import clear_output, display

# %%
lookup_table_builder.CANDIDATE_BLOCKS
# Out:
# ['ir_k3_e1',
#  'ir_k3_s2',
#  'ir_k3_e3',
#  'ir_k3_e6',
#  'ir_k5_e1',
#  'ir_k5_s2',
#  'ir_k5_e3',
#  'ir_k5_e6',
#  'skip']

# %%
candidates = lookup_table_builder.CANDIDATE_BLOCKS
search_length = len(lookup_table_builder.SEARCH_SPACE['input_shape'])

# %%
# imagenet
np.random.seed(1)

# cifar 10
# np.random.seed(2)

# cifar 100
# np.random.seed(3)

# %%
n = 9

for _ in range(n):
    random_search = np.random.sample(search_length) * len(candidates)
    random_search = random_search.astype(int)
    
    rs_arch = np.take(candidates, random_search).tolist()
    rs_arch = [[x] for x in rs_arch]
    
    print(rs_arch)
    print('\n')
# Out:
# [['ir_k3_e6'], ['ir_k5_e3'], ['ir_k3_e1'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e1'], ['ir_k3_s2'], ['ir_k3_e6'], ['ir_k3_e6'], ['ir_k5_e1'], ['ir_k3_e6'], ['ir_k5_e3'], ['ir_k3_s2'], ['ir_k5_e6'], ['ir_k3_e1'], ['ir_k5_e3'], ['ir_k3_e6']]
#
#
# [['ir_k5_s2'], ['ir_k3_s2'], ['ir_k3_s2'], ['ir_k5_e6'], ['skip'], ['ir_k3_e3'], ['ir_k5_e3'], ['ir_k5_e6'], ['skip'], ['ir_k3_e1'], ['ir_k3_e1'], ['ir_k3_s2'], ['ir_k5_e6'], ['ir_k3_e1'], ['ir_k3_e6'], ['skip'], ['ir_k5_e1']]
#
#
# [['ir_k5_e3'], ['ir_k3_e3'], ['ir_k5_e3'], ['ir_k5_e6'], ['ir_k3_e1'], ['ir_k5_e3'], ['skip'], ['ir_k5_e3'], ['ir_k3_e3'], ['ir_k5_e6'], ['ir_k3_e1'], ['ir_k5_e1'], ['skip'], ['ir_k3_e3'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e1']]
#
#
# [['ir_k5_e3'], ['ir_k3_s2'], ['ir_k3_e3'], ['ir_k5_e1'], ['ir_k3_e1'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k5_s2'], ['ir_k5_e3'], ['ir_k3_e1'], ['ir_k3_e6'], ['ir_k5_e3'], ['ir_k3_e6'], ['ir_k3_e1'], ['ir_k5_e1'], ['ir_k5_s2'], ['ir_k5_e1']]
#
#
# ...

# %%
# Out:
# [['ir_k5_e1'], ['ir_k5_e1'], ['ir_k5_e3'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e1'], ['ir_k3_e3'], ['ir_k3_e1'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e1'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e3'], ['ir_k5_e1'], ['ir_k5_e1']]

# %%
    "0903_cifar10_rs1": {
            "block_op_type": [['ir_k3_e6'], ['ir_k3_e1'], ['ir_k5_e1'], ['ir_k3_e6'], ['ir_k3_e6'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k3_e3'], ['ir_k5_s2'], ['ir_k5_e1'], ['ir_k3_s2'], ['ir_k5_e1'], ['ir_k3_s2'], ['ir_k5_e6'], ['ir_k5_e6']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },
    "0903_cifar10_rs2": {
            "block_op_type": [['ir_k5_e1'], ['ir_k5_e6'], ['ir_k3_e1'], ['ir_k5_e1'], ['ir_k3_e1'], ['ir_k3_e6'], ['ir_k3_e1'], ['ir_k3_s2'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k3_e1'], ['ir_k3_s2'], ['ir_k3_e6'], ['ir_k5_e1'], ['ir_k3_s2'], ['ir_k5_s2'], ['ir_k5_e1']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },
    "0903_cifar10_rs3": {
            "block_op_type": [['ir_k5_e1'], ['ir_k3_e6'], ['ir_k5_e6'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k5_e3'], ['skip'], ['ir_k5_e1'], ['skip'], ['ir_k3_e6'], ['ir_k5_s2'], ['ir_k3_e6'], ['ir_k3_e6'], ['ir_k5_e3'], ['ir_k5_e1'], ['skip'], ['ir_k5_e1']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs4": {
            "block_op_type": [['ir_k3_e1'], ['ir_k3_e6'], ['ir_k5_e6'], ['ir_k3_e6'], ['ir_k3_e1'], ['ir_k3_e3'], ['ir_k3_e1'], ['skip'], ['skip'], ['ir_k5_e6'], ['ir_k5_s2'], ['ir_k5_e3'], ['ir_k3_s2'], ['ir_k3_e3'], ['ir_k5_e1'], ['ir_k3_e6'], ['ir_k3_e1']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs5": {
            "block_op_type": [['skip'], ['ir_k3_e6'], ['ir_k5_e1'], ['ir_k3_e3'], ['ir_k3_e3'], ['ir_k3_e6'], ['ir_k5_e6'], ['ir_k5_e3'], ['ir_k3_e6'], ['ir_k3_e1'], ['ir_k5_e6'], ['ir_k3_e3'], ['ir_k5_s2'], ['ir_k3_e1'], ['ir_k5_s2'], ['ir_k3_e6'], ['ir_k5_e1']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs6": {
            "block_op_type": [['ir_k3_e6'], ['ir_k3_e6'], ['ir_k5_e1'], ['skip'], ['ir_k3_s2'], ['ir_k3_e3'], ['ir_k3_e1'], ['ir_k5_e3'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k3_e6'], ['ir_k5_s2'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k5_e6'], ['ir_k5_e6'], ['ir_k3_s2']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs7": {
            "block_op_type": [['ir_k5_e6'], ['ir_k5_e3'], ['ir_k5_e6'], ['ir_k5_e1'], ['ir_k3_s2'], ['skip'], ['ir_k5_s2'], ['ir_k3_e6'], ['ir_k3_e3'], ['skip'], ['ir_k3_e6'], ['ir_k5_e1'], ['ir_k5_s2'], ['ir_k5_e6'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k5_s2']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs8": {
            "block_op_type":[['ir_k5_e1'], ['ir_k5_e1'], ['ir_k5_e3'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e1'], ['ir_k3_e3'], ['ir_k3_e1'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e1'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e3'], ['ir_k5_e1'], ['ir_k5_e1']], 
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar100_rs1": {
            "block_op_type": [['ir_k5_e1'], ['ir_k5_e3'], ['ir_k3_e3'], ['ir_k5_e1'], ['skip'], ['skip'], ['ir_k3_s2'], ['ir_k3_s2'], ['ir_k3_e1'], ['ir_k3_e6'], ['ir_k3_e1'], ['ir_k5_e1'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k5_e3'], ['ir_k5_s2'], ['ir_k3_e1']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar100_rs2": {
            "block_op_type": [['ir_k5_s2'], ['ir_k3_e3'], ['ir_k3_e6'], ['ir_k3_e3'], ['ir_k5_e3'], ['ir_k3_e6'], ['ir_k3_s2'], ['ir_k5_e1'], ['ir_k5_e6'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e6'], ['skip'], ['skip'], ['ir_k5_e3'], ['skip'], ['ir_k5_e6']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar100_rs3": {
            "block_op_type": [['ir_k3_e6'], ['ir_k3_e1'], ['ir_k5_s2'], ['ir_k5_s2'], ['ir_k3_e6'], ['ir_k3_e3'], ['ir_k3_e6'], ['ir_k5_e1'], ['ir_k3_e3'], ['ir_k3_e3'], ['ir_k5_e1'], ['ir_k5_e6'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k3_e3'], ['ir_k5_e1'], ['ir_k3_s2']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar100_rs4": {
            "block_op_type": [['ir_k3_s2'], ['ir_k5_e1'], ['ir_k3_e1'], ['ir_k5_e1'], ['ir_k3_e6'], ['ir_k5_e3'], ['ir_k5_e3'], ['ir_k5_e3'], ['ir_k5_e3'], ['ir_k3_e6'], ['ir_k5_e3'], ['ir_k3_e6'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k5_e1'], ['ir_k3_e1'], ['ir_k3_e3']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar100_rs5": {
            "block_op_type": [['skip'], ['ir_k3_e3'], ['ir_k5_e3'], ['ir_k5_s2'], ['ir_k5_e3'], ['ir_k5_e1'], ['ir_k5_s2'], ['ir_k3_e1'], ['ir_k3_e1'], ['ir_k3_s2'], ['ir_k3_s2'], ['ir_k3_e1'], ['ir_k3_s2'], ['ir_k5_e1'], ['ir_k3_s2'], ['skip'], ['ir_k5_e3']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar100_rs6": {
            "block_op_type": [['ir_k5_e1'], ['ir_k5_e3'], ['ir_k3_e3'], ['skip'], ['ir_k5_e6'], ['ir_k5_e3'], ['ir_k5_e1'], ['ir_k5_e6'], ['ir_k5_e3'], ['ir_k5_s2'], ['skip'], ['ir_k5_s2'], ['ir_k3_e6'], ['ir_k5_e1'], ['ir_k3_s2'], ['ir_k3_s2'], ['ir_k5_e3']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar100_rs7": {
            "block_op_type": [['ir_k5_e6'], ['skip'], ['ir_k5_e6'], ['ir_k5_e1'], ['ir_k3_e1'], ['ir_k5_e1'], ['skip'], ['ir_k5_e6'], ['ir_k5_e1'], ['ir_k5_e1'], ['ir_k3_s2'], ['ir_k3_s2'], ['ir_k3_e1'], ['skip'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k3_e6']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar100_rs8": {
            "block_op_type": [['ir_k3_e1'], ['ir_k3_s2'], ['ir_k5_e3'], ['ir_k5_s2'], ['ir_k5_e1'], ['ir_k3_e3'], ['ir_k5_s2'], ['skip'], ['ir_k3_e6'], ['ir_k3_e1'], ['ir_k3_e1'], ['ir_k3_e1'], ['skip'], ['ir_k5_e1'], ['ir_k5_e6'], ['ir_k3_s2'], ['ir_k3_e3']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },

# %%
    "0903_cifar10_rs1": {
            "block_op_type": [['ir_k3_e6'], ['ir_k3_e1'], ['ir_k5_e1'], ['ir_k3_e6'], ['ir_k3_e6'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k3_e3'], ['ir_k5_s2'], ['ir_k5_e1'], ['ir_k3_s2'], ['ir_k5_e1'], ['ir_k3_s2'], ['ir_k5_e6'], ['ir_k5_e6']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },
    "0903_cifar10_rs2": {
            "block_op_type": [['ir_k5_e1'], ['ir_k5_e6'], ['ir_k3_e1'], ['ir_k5_e1'], ['ir_k3_e1'], ['ir_k3_e6'], ['ir_k3_e1'], ['ir_k3_s2'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k3_e1'], ['ir_k3_s2'], ['ir_k3_e6'], ['ir_k5_e1'], ['ir_k3_s2'], ['ir_k5_s2'], ['ir_k5_e1']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },
    "0903_cifar10_rs3": {
            "block_op_type": [['ir_k5_e1'], ['ir_k3_e6'], ['ir_k5_e6'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k5_e3'], ['skip'], ['ir_k5_e1'], ['skip'], ['ir_k3_e6'], ['ir_k5_s2'], ['ir_k3_e6'], ['ir_k3_e6'], ['ir_k5_e3'], ['ir_k5_e1'], ['skip'], ['ir_k5_e1']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs4": {
            "block_op_type": [['ir_k3_e1'], ['ir_k3_e6'], ['ir_k5_e6'], ['ir_k3_e6'], ['ir_k3_e1'], ['ir_k3_e3'], ['ir_k3_e1'], ['skip'], ['skip'], ['ir_k5_e6'], ['ir_k5_s2'], ['ir_k5_e3'], ['ir_k3_s2'], ['ir_k3_e3'], ['ir_k5_e1'], ['ir_k3_e6'], ['ir_k3_e1']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs5": {
            "block_op_type": [['skip'], ['ir_k3_e6'], ['ir_k5_e1'], ['ir_k3_e3'], ['ir_k3_e3'], ['ir_k3_e6'], ['ir_k5_e6'], ['ir_k5_e3'], ['ir_k3_e6'], ['ir_k3_e1'], ['ir_k5_e6'], ['ir_k3_e3'], ['ir_k5_s2'], ['ir_k3_e1'], ['ir_k5_s2'], ['ir_k3_e6'], ['ir_k5_e1']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs6": {
            "block_op_type": [['ir_k3_e6'], ['ir_k3_e6'], ['ir_k5_e1'], ['skip'], ['ir_k3_s2'], ['ir_k3_e3'], ['ir_k3_e1'], ['ir_k5_e3'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k3_e6'], ['ir_k5_s2'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k5_e6'], ['ir_k5_e6'], ['ir_k3_s2']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs7": {
            "block_op_type": [['ir_k5_e6'], ['ir_k5_e3'], ['ir_k5_e6'], ['ir_k5_e1'], ['ir_k3_s2'], ['skip'], ['ir_k5_s2'], ['ir_k3_e6'], ['ir_k3_e3'], ['skip'], ['ir_k3_e6'], ['ir_k5_e1'], ['ir_k5_s2'], ['ir_k5_e6'], ['ir_k5_s2'], ['ir_k3_s2'], ['ir_k5_s2']],
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },        
    "0903_cifar10_rs8": {
            "block_op_type":[['ir_k5_e1'], ['ir_k5_e1'], ['ir_k5_e3'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e1'], ['ir_k3_e3'], ['ir_k3_e1'], ['ir_k5_s2'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e1'], ['ir_k3_e3'], ['ir_k3_s2'], ['ir_k3_e3'], ['ir_k5_e1'], ['ir_k5_e1']], 
            "block_cfg": {
                    "first": [32, 1],
                    "stages": [
                        [[6, 16, 1, 1]],                                                        # stage 1
                        [[6, 24, 1, 1]],  [[6, 24, 1, 1]],  # stage 2
                        [[6, 32, 1, 2]],  [[6, 32, 1, 1]],          [[6, 32, 1, 1]],  # stage 3
                        [[6, 64, 1, 2]],  [[6, 64, 1, 1]],          [[6, 64, 1, 1]],  [[6, 64, 1, 1]],  # stage 4
                        [[1, 96, 1, 1]], [[6, 96, 1, 1]],         [[6, 96, 1, 1]], # stage 5
                        [[1, 160, 1, 2]], [[6, 160, 1, 1]],         [[6, 160, 1, 1]], # stage 6
                        [[1, 320, 1, 1]],                                                       # stage 7
                    ],
                    "backbone": [num for num in range(18)],
                },
            },
